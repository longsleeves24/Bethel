# %%
# Import libraries

import pandas as pd
import numpy as np

# %%
# Scrape a data set

redding = pd.read_html("https://en.wikipedia.org/wiki/Redding,_California")

# %%
# Getting weather data for Redding, CA

weather = redding[1]

# %%
# display Redding's weather data

display(weather)
# Out:
#    Climate data for Redding Regional Airport, California (1991–2020 normals,[a] extremes 1893–present[b])  \
#                                                                                                     Month
# 0                                 Record high °F (°C)
# 1                                Mean maximum °F (°C)
# 2                          Mean daily maximum °F (°C)
# 3                                  Daily mean °F (°C)
# 4                          Mean daily minimum °F (°C)
# 5                                Mean minimum °F (°C)
# 6                                  Record low °F (°C)
# 7                   Average precipitation inches (mm)
# 8                        Average snowfall inches (cm)
# 9              Average precipitation days (≥ 0.01 in)
# 10                      Average snowy days (≥ 0.1 in)
# 11                             Source 1: NOAA[20][23]
# 12                                 Source 2: WRCC[24]
#
# ...
